# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodrigo470-1/beginning--bioinformatics/blob/main/bioinformatics_module03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 984
b=831
multiplication = a**2 + b**2
print (multiplication)
# Out:
# 1658817

# %%
array = ['xYmN5yNuT0CqqplqzWdidaCoboLjJo7jjqRUW5GPWNcSJktNE8oFgA9eZddNQ14uJ39I8qcpNbCVlrYK3mhIZgPaApusL5rsnkkyOYEt2rWF335xt8oUxIygB1jTVaMP8zJc9k0MPPvqQ6S5JoF9zJF34VUGiGvj1mitratust7kHmdt7EMq4uQ3k1GIbGppnswrlx.']
string_cut = array [0]
cut = string_cut[88:92] +' '+ string_cut[161:169]
print (cut)
# Out:
# Apus mitratus

# %%
a = 4910
b = 9341
c = b - a
array = []
for i in range (c):
  if a % 2 == 1:
    array.append(a)
  a += 1


number = sum(array)
print (number)
print (array)
# Out:
# 15781875
# ...

# %%
with open('rosalind_ini5.txt', 'r') as f:
    for i, line in enumerate(f):
        # Enumerate gives 0-indexed line numbers, so (i + 1) gives the 1-indexed line number
        # Print only the odd-numbered lines (1st, 3rd, 5th, etc.)
        if (i + 1) % 2 != 1:
            print(line.strip())
# The 'array' and 'b = a.read()' were removed as they did not align with the typical Rosalind ini5 problem requirements.
# Out:
# Some things in life are bad, they can really make you mad
# Other things just make you swear and curse
# When you're chewing on life's gristle, don't grumble give a whistle
# This will help things turn out for the best
# Always look on the bright side of life
# Always look on the right side of life
# If life seems jolly rotten, there's something you've forgotten
# And that's to laugh and smile and dance and sing
# When you're feeling in the dumps, don't be silly, chumps
# Just purse your lips and whistle, that's the thing
# So, always look on the bright side of death
# Just before you draw your terminal breath
# Life's a counterfeit and when you look at it
# Life's a laugh and death's the joke, it's true
# You see, it's all a show, keep them laughing as you go
# Just remember the last laugh is on you
# Always look on the bright side of life
# And always look on the right side of life
# Always look on the bright side of life
# And always look on the right side of life

# %%
explanation_text = """
Line-by-line explanation for cell SUVKuj9MhxSp:

1.  `with open('rosalind_ini5.txt', 'r') as f:`
    This line opens the file named 'rosalind_ini5.txt' in read mode ('r'). The `with` statement ensures that the file is automatically closed when the block of code is exited, even if errors occur. The file object is assigned to the variable `f`.

2.  `for i, line in enumerate(f):`
    This loop iterates over each line in the file `f`. The `enumerate()` function is used here to get both the index (`i`) and the content (`line`) of each item in the iterable `f`. The index `i` starts from 0.

3.  `# Enumerate gives 0-indexed line numbers, so (i + 1) gives the 1-indexed line number`
    This is a comment explaining that `i` is 0-indexed, so adding 1 to it will give the human-readable 1-indexed line number.

4.  `# Print only the odd-numbered lines (1st, 3rd, 5th, etc.)`
    This is another comment clarifying the purpose of the conditional statement that follows.

5.  `if (i + 1) % 2 != 1:`
    This is the conditional statement that checks if a line should be printed. `(i + 1)` gives the 1-indexed line number. The modulo operator `% 2` checks if the line number is odd or even. If `(i + 1)` is odd, `(i + 1) % 2` will be 1. The condition `!= 1` means it will be `True` for even line numbers (where `(i + 1) % 2` is 0) and `False` for odd line numbers (where `(i + 1) % 2` is 1). Therefore, this condition is designed to print **even** numbered lines, not odd ones as the comment suggests.

6.  `print(line.strip())`
    If the condition in line 5 is true (i.e., the line number is even), this line prints the current `line` after removing any leading or trailing whitespace characters (including newline characters like `\n`) using the `strip()` method.

7.  `# The 'array' and 'b = a.read()' were removed as they did not align with the typical Rosalind ini5 problem requirements.`
    This is a comment explaining why some previously existing code (related to `array` and `b = a.read()`) was removed. It indicates that the goal of this cell is specifically to address the Rosalind ini5 problem, which typically involves processing lines based on their index.
"""

with open('code_explanation.txt', 'w') as f_out:
    f_out.write(explanation_text)

print("Explanation written to 'code_explanation.txt'")
# Out:
# Explanation written to 'code_explanation.txt'

# %%
input = "We tried list and we tried dicts also we tried Zen"
d ={}
for output in input.split():
 d [output] = d.get(output, 0) + 1
for output, c in d.items():
 print (output, c)

# %%
input = "We tried list and we tried dicts also we tried Zen"
d ={}
c = 0
for output in input.split():
 d [output] = ''
 print (d)
 if output in d.get(output,c):
  d[output] = c+1
 #if output != input.split():

print (d)
# Out:
# {'We': ''}
# {'We': '', 'tried': ''}
# {'We': '', 'tried': '', 'list': ''}
# {'We': '', 'tried': '', 'list': '', 'and': ''}
# {'We': '', 'tried': '', 'list': '', 'and': '', 'we': ''}
# {'We': '', 'tried': '', 'list': '', 'and': '', 'we': ''}
# {'We': '', 'tried': '', 'list': '', 'and': '', 'we': '', 'dicts': ''}
# {'We': '', 'tried': '', 'list': '', 'and': '', 'we': '', 'dicts': '', 'also': ''}
# {'We': '', 'tried': '', 'list': '', 'and': '', 'we': '', 'dicts': '', 'also': ''}
# {'We': '', 'tried': '', 'list': '', 'and': '', 'we': '', 'dicts': '', 'also': ''}
# {'We': '', 'tried': '', 'list': '', 'and': '', 'we': '', 'dicts': '', 'also': '', 'Zen': ''}
# {'We': '', 'tried': '', 'list': '', 'and': '', 'we': '', 'dicts': '', 'also': '', 'Zen': ''}
